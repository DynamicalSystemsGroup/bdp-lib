# %%
from pathlib import Path
import jsonref

schema_path = Path("../src/bdp_lib/schemas/bdp.schema.json").absolute()

with schema_path.open() as file:
    schema = jsonref.load(file, base_uri=schema_path.as_uri())

schema
# Out:
# {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/bdp.schema.json',
#  '$schema': 'http://json-schema.org/draft-07/schema#',
#  'title': 'Block Diagram Protocol Schema',
#  'type': 'object',
#  'additionalProperties': False,
#  'description': 'This schema is used to validate the JSON file that is used to store the block diagram protocol. There are two components, a toolbox which describes the abstract blocks and spaces and the model which has the actual instances of the toolbox - processors, wires and systems.',
#  'properties': {'Toolbox': {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/toolbox.schema.json',
#    '$schema': 'http://json-schema.org/draft-07/schema#',
#    'title': 'Toolbox Schema',
#    'type': 'object',
#    'additionalProperties': False,
#    'description': 'This schema is used for describing a toolbox in bdp-lib.',
#    'properties': {'Spaces': {'type': 'array',
#      'description': 'A list of spaces in the block diagram protocol that follow the space schema. It defines the abstract classes of blocks and spaces which models will instantiate.',
#      'title': 'Spaces',
#      'items': {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/space.schema.json',
#       '$schema': 'http://json-schema.org/draft-07/schema#',
#       'title': 'Space Schema',
#       'type': 'object',
#       'additionalProperties': False,
#       'properties': {'ID': {'title': 'ID',
#         'description': 'The unique identifier of the space.',
#         'type': 'string'},
#        'Name': {'type': 'string',
#         'description': 'The name of the space.',
#         'title': 'Name'},
#        'Description': {'type': 'string',
#         'description': 'The description of the space.',
#         'title': 'Description'}},
#       'required': ['ID', 'Name']}},
#     'Blocks': {'type': 'array',
#      'description': 'A list of blocks in the block diagram protocol that follow the block schema.',
#      'title': 'Blocks',
#      'items': {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/block.schema.json',
#       '$schema': 'http://json-schema.org/draft-07/schema#',
#       'title': 'Block Schema',
#       'type': 'object',
#       'additionalProperties': False,
#       'properties': {'ID': {'type': 'string',
#         'title': 'ID',
#         'description': 'A unique identifier for the block.'},
#        'Name': {'type': 'string',
#         'title': 'Name',
#         'description': 'The name of the block.'},
#        'Description': {'type': 'string',
#         'title': 'Description',
#         'description': 'A description of the block.'},
#        'Domain': {'type': 'array',
#         'title': 'Domain',
#         'description': 'The domain of the block which are IDs of spaces. Spaces may be repeated or it may be an empty array.',
#         'items': {'type': 'string'}},
#        'Codomain': {'type': 'array',
#         'title': 'Codomain',
#         'description': 'The codomain of the block which are IDs of spaces. Spaces may be repeated or it may be an empty array.',
#         'items': {'type': 'string'}}},
#       'required': ['ID', 'Name', 'Domain', 'Codomain']}}},
#    'required': ['Spaces', 'Blocks']},
#   'Model': {'type': 'object',
#    'description': 'A model of the instances of processors, wires and systems.',
#    'title': 'Model',
#    'items': {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/model.schema.json',
#     '$schema': 'http://json-schema.org/draft-07/schema#',
#     'title': 'Model Schema',
#     'type': 'object',
#     'additionalProperties': False,
#     'description': 'This schema is used to describe a model in bdp-lib which is the actual instances of the toolbox which it would be paired with in the large bdp schema.',
#     'properties': {'Processors': {'type': 'array',
#       'description': 'A list of processors in the block diagram protocol that follow the processor schema.',
#       'title': 'Processors',
#       'items': {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/processor.schema.json',
#        '$schema': 'http://json-schema.org/draft-07/schema#',
#        'title': 'Processor Schema',
#        'type': 'object',
#        'additionalProperties': False,
#        'properties': {'ID': {'type': 'string',
#          'title': 'ID',
#          'description': 'A unique identifier for the processor.'},
#         'Name': {'type': 'string',
#          'title': 'Name',
#          'description': 'The name of the processor.'},
#         'Description': {'type': 'string',
#          'title': 'Description',
#          'description': 'A description of the processor.'},
#         'Parent': {'type': 'string',
#          'title': 'Parent',
#          'description': 'The ID of the block that the processor is an instance of.'},
#         'Ports': {'type': 'array',
#          'title': 'Ports',
#          'description': 'The IDs of spaces which must match the domain of the parent block.',
#          'items': {'type': 'string'}},
#         'Terminals': {'type': 'array',
#          'title': 'Terminals',
#          'description': 'The IDs of spaces which must match the codomain of the parent block.',
#          'items': {'type': 'string'}}},
#        'required': ['ID', 'Name', 'Parent', 'Port', 'Terminals']}},
#      'Wires': {'type': 'array',
#       'description': 'A list of wires in the block diagram protocol that follow the wire schema.',
#       'title': 'Wires',
#       'items': {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/wire.schema.json',
#        '$schema': 'http://json-schema.org/draft-07/schema#',
#        'title': 'Wire Schema',
#        'type': 'object',
#        'additionalProperties': False,
#        'properties': {'ID': {'type': 'string',
#          'title': 'ID',
#          'description': 'A unique identifier for the wire.'},
#         'Parent': {'type': 'string',
#          'title': 'Parent',
#          'description': 'The ID of the space that the wire is passing.'},
#         'Source': {'type': 'object',
#          'title': 'Source',
#          'description': 'The source of the wire/space.',
#          'properties': {'Processor': {'type': 'string',
#            'title': 'Processor',
#            'description': 'The ID of the processor that the wire is coming from.'},
#           'Index': {'type': 'integer',
#            'title': 'Index',
#            'description': 'The index of the terminal that the wire is coming from.'}}},
#         'Target': {'type': 'object',
#          'title': 'Target',
#          'description': 'The target of the wire/space.',
#          'properties': {'Processor': {'type': 'string',
#            'title': 'Processor',
#            'description': 'The ID of the processor that the wire is going to.'},
#           'Index': {'type': 'integer',
#            'title': 'Index',
#            'description': 'The index of the port that the wire is going to.'}}}},
#        'required': ['ID',
#         'Parent',
#         'SourceBlock',
#         'TargetBlock',
#         'SourceIndex',
#         'TargetIndex']}},
#      'Systems': {'type': 'array',
#       'description': 'A list of systems in the block diagram protocol that follow the system schema.',
#       'title': 'Systems',
#       'items': {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/system.schema.json',
#        '$schema': 'http://json-schema.org/draft-07/schema#',
#        'title': 'System Schema',
#        'type': 'object',
#        'additionalProperties': False,
#        'properties': {'ID': {'type': 'string',
#          'title': 'ID',
#          'description': 'A unique identifier for the system.'},
#         'Name': {'type': 'string',
#          'title': 'Name',
#          'description': 'The name of the system.'},
#         'Description': {'type': 'string',
#          'title': 'Description',
#          'description': 'A description of the system.'},
#         'ConcreteBlocks': {'type': 'array',
#          'title': 'ConcreteBlocks',
#          'description': 'A list of concrete block IDs that are part of the system.',
#          'items': {'type': 'string'}},
#         'Wires': {'type': 'array',
#          'title': 'Wires',
#          'description': 'A list of wire IDs that are part of the system.',
#          'items': {'type': 'string'}}},
#        'required': ['ID', 'Name', 'ConcreteBlocks', 'Wires']}}},
#     'required': ['Processors', 'Wires', 'Systems']}}},
#  'required': ['Toolbox', 'Model']}

# %%
schema = {}

# %%
import json
import os

os.chdir("../src/bdp_lib/schemas")

import jsonref
def format_json_schema_draft07(schema, indent=0):
    """Formats a Draft-07 JSON Schema into a readable type definition."""
    spacing = "  " * indent
    
    if "type" in schema:
        if schema["type"] == "object":
            properties = schema.get("properties", {})
            required = schema.get("required", [])
            formatted_props = "\n".join(
                f"{spacing}  {key}: {format_json_schema_draft07(value, indent + 1)}{' (required)' if key in required else ''}"
                for key, value in properties.items()
            )
            return f"object {{\n{formatted_props}\n{spacing}}}"
        elif schema["type"] == "array":
            items = schema.get("items", {})
            return f"array[{format_json_schema_draft07(items, indent)}]"
        else:
            return schema["type"]
    
    elif "$ref" in schema:
        return f"ref({schema['$ref']})"
    
    elif "enum" in schema:
        return f"enum({', '.join(map(str, schema['enum']))})"
    
    elif "anyOf" in schema:
        return " | ".join(format_json_schema_draft07(sub_schema, indent) for sub_schema in schema["anyOf"])
    
    elif "oneOf" in schema:
        return "one of (" + ", ".join(format_json_schema_draft07(sub_schema, indent) for sub_schema in schema["oneOf"]) + ")"
    
    elif "allOf" in schema:
        return "all of (" + ", ".join(format_json_schema_draft07(sub_schema, indent) for sub_schema in schema["allOf"]) + ")"
    
    return "unknown"


with open("bdp.schema.json", "r") as file:
    data = jsonref.load(file)  # Parses JSON into a Python dictionary

#format_json_schema_draft07(data)

# %%
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/urllib/request.py:1503, in FileHandler.open_local_file(self, req)
#    1502 try:
# -> 1503     stats = os.stat(localfile)
#    1504     size = stats.st_size
#
# FileNotFoundError: [Errno 2] No such file or directory: '/toolbox.schema.json'
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/jsonref.py:130, in JsonRef.callback(self)
#     129 try:
# --> 130     base_doc = self.loader(uri)
#     131 except Exception as e:
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/jsonref.py:255, in jsonloader(uri, **kwargs)
#     253 else:
#     254     # Otherwise, pass off to urllib and assume utf-8
# --> 255     with urlopen(uri) as content:
#     256         result = json.loads(content.read().decode("utf-8"), **kwargs)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/urllib/request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/urllib/request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/urllib/request.py:534, in OpenerDirector._open(self, req, data)
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/urllib/request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     493 func = getattr(handler, meth_name)
# --> 494 result = func(*args)
#     495 if result is not None:
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/urllib/request.py:1481, in FileHandler.file_open(self, req)
#    1480 else:
# -> 1481     return self.open_local_file(req)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/urllib/request.py:1520, in FileHandler.open_local_file(self, req)
#    1519 except OSError as exp:
# -> 1520     raise URLError(exp)
#    1521 raise URLError('file not on local host')
#
# URLError: <urlopen error [Errno 2] No such file or directory: '/toolbox.schema.json'>
#
# The above exception was the direct cause of the following exception:
#
# JsonRefError                              Traceback (most recent call last)
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/core/formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/lib/pretty.py:692, in _dict_pprinter_factory.<locals>.inner(obj, p, cycle)
#     690     p.pretty(key)
#     691     p.text(': ')
# --> 692     p.pretty(obj[key])
#     693 p.end_group(step, end)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/lib/pretty.py:692, in _dict_pprinter_factory.<locals>.inner(obj, p, cycle)
#     690     p.pretty(key)
#     691     p.text(': ')
# --> 692     p.pretty(obj[key])
#     693 p.end_group(step, end)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/lib/pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/proxytypes.py:121, in ProxyMetaClass._no_proxy.<locals>.wrapper(self, *args, **kwargs)
#     119 _osa(self, "__notproxied__", True)
#     120 try:
# --> 121     return method(self, *args, **kwargs)
#     122 finally:
#     123     _osa(self, "__notproxied__", notproxied)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/jsonref.py:199, in JsonRef.__repr__(self)
#     197 def __repr__(self):
#     198     if hasattr(self, "cache") or self.load_on_repr:
# --> 199         return repr(self.__subject__)
#     200     return "JsonRef(%r)" % self.__reference__
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/proxytypes.py:163, in Proxy.__getattribute__(self, attr)
#     161 if Proxy._should_proxy(self, attr):
#     162     return getattr(self.__subject__, attr)
# --> 163 return _oga(self, attr)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/proxytypes.py:121, in ProxyMetaClass._no_proxy.<locals>.wrapper(self, *args, **kwargs)
#     119 _osa(self, "__notproxied__", True)
#     120 try:
# --> 121     return method(self, *args, **kwargs)
#     122 finally:
#     123     _osa(self, "__notproxied__", notproxied)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/proxytypes.py:243, in LazyProxy.__subject__(self)
#     240 except AttributeError:
#     241     pass
# --> 243 self.cache = super(LazyProxy, self).__subject__
#     244 return self.cache
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/proxytypes.py:121, in ProxyMetaClass._no_proxy.<locals>.wrapper(self, *args, **kwargs)
#     119 _osa(self, "__notproxied__", True)
#     120 try:
# --> 121     return method(self, *args, **kwargs)
#     122 finally:
#     123     _osa(self, "__notproxied__", notproxied)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/proxytypes.py:227, in CallbackProxy.__subject__(self)
#     225 @property
#     226 def __subject__(self):
# --> 227     return self.callback()
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/proxytypes.py:121, in ProxyMetaClass._no_proxy.<locals>.wrapper(self, *args, **kwargs)
#     119 _osa(self, "__notproxied__", True)
#     120 try:
# --> 121     return method(self, *args, **kwargs)
#     122 finally:
#     123     _osa(self, "__notproxied__", notproxied)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/jsonref.py:132, in JsonRef.callback(self)
#     130         base_doc = self.loader(uri)
#     131     except Exception as e:
# --> 132         raise self._error(
#     133             "%s: %s" % (e.__class__.__name__, str(e)), cause=e
#     134         ) from e
#     135     base_doc = _replace_refs(
#     136         base_doc, **{**self._ref_kwargs, "base_uri": uri, "recursing": False}
#     137     )
#     138 else:
#
# JsonRefError: Error while resolving `file://./toolbox.schema.json`: URLError: <urlopen error [Errno 2] No such file or directory: '/toolbox.schema.json'>

# %%
result
# Out:
# {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/bdp.schema.json',
#  '$schema': 'http://json-schema.org/draft-07/schema#',
#  'title': 'Block Diagram Protocol Schema',
#  'type': 'object',
#  'additionalProperties': False,
#  'description': 'This schema is used to validate the JSON file that is used to store the block diagram protocol. There are two components, a toolbox which describes the abstract blocks and spaces and the model which has the actual instances of the toolbox - processors, wires and systems.',
#  'properties': {'Toolbox': {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/toolbox.schema.json',
#    '$schema': 'http://json-schema.org/draft-07/schema#',
#    'title': 'Toolbox Schema',
#    'type': 'object',
#    'additionalProperties': False,
#    'description': 'This schema is used for describing a toolbox in bdp-lib.',
#    'properties': {'Spaces': {'type': 'array',
#      'description': 'A list of spaces in the block diagram protocol that follow the space schema. It defines the abstract classes of blocks and spaces which models will instantiate.',
#      'title': 'Spaces',
#      'items': {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/space.schema.json',
#       '$schema': 'http://json-schema.org/draft-07/schema#',
#       'title': 'Space Schema',
#       'type': 'object',
#       'additionalProperties': False,
#       'properties': {'ID': {'title': 'ID',
#         'description': 'The unique identifier of the space.',
#         'type': 'string'},
#        'Name': {'type': 'string',
#         'description': 'The name of the space.',
#         'title': 'Name'},
#        'Description': {'type': 'string',
#         'description': 'The description of the space.',
#         'title': 'Description'}},
#       'required': ['ID', 'Name']}},
#     'Blocks': {'type': 'array',
#      'description': 'A list of blocks in the block diagram protocol that follow the block schema.',
#      'title': 'Blocks',
#      'items': {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/block.schema.json',
#       '$schema': 'http://json-schema.org/draft-07/schema#',
#       'title': 'Block Schema',
#       'type': 'object',
#       'additionalProperties': False,
#       'properties': {'ID': {'type': 'string',
#         'title': 'ID',
#         'description': 'A unique identifier for the block.'},
#        'Name': {'type': 'string',
#         'title': 'Name',
#         'description': 'The name of the block.'},
#        'Description': {'type': 'string',
#         'title': 'Description',
#         'description': 'A description of the block.'},
#        'Domain': {'type': 'array',
#         'title': 'Domain',
#         'description': 'The domain of the block which are IDs of spaces. Spaces may be repeated or it may be an empty array.',
#         'items': {'type': 'string'}},
#        'Codomain': {'type': 'array',
#         'title': 'Codomain',
#         'description': 'The codomain of the block which are IDs of spaces. Spaces may be repeated or it may be an empty array.',
#         'items': {'type': 'string'}}},
#       'required': ['ID', 'Name', 'Domain', 'Codomain']}}},
#    'required': ['Spaces', 'Blocks']},
#   'Model': {'type': 'object',
#    'description': 'A model of the instances of processors, wires and systems.',
#    'title': 'Model',
#    'items': {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/model.schema.json',
#     '$schema': 'http://json-schema.org/draft-07/schema#',
#     'title': 'Model Schema',
#     'type': 'object',
#     'additionalProperties': False,
#     'description': 'This schema is used to describe a model in bdp-lib which is the actual instances of the toolbox which it would be paired with in the large bdp schema.',
#     'properties': {'Processors': {'type': 'array',
#       'description': 'A list of processors in the block diagram protocol that follow the processor schema.',
#       'title': 'Processors',
#       'items': {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/processor.schema.json',
#        '$schema': 'http://json-schema.org/draft-07/schema#',
#        'title': 'Processor Schema',
#        'type': 'object',
#        'additionalProperties': False,
#        'properties': {'ID': {'type': 'string',
#          'title': 'ID',
#          'description': 'A unique identifier for the processor.'},
#         'Name': {'type': 'string',
#          'title': 'Name',
#          'description': 'The name of the processor.'},
#         'Description': {'type': 'string',
#          'title': 'Description',
#          'description': 'A description of the processor.'},
#         'Parent': {'type': 'string',
#          'title': 'Parent',
#          'description': 'The ID of the block that the processor is an instance of.'},
#         'Ports': {'type': 'array',
#          'title': 'Ports',
#          'description': 'The IDs of spaces which must match the domain of the parent block.',
#          'items': {'type': 'string'}},
#         'Terminals': {'type': 'array',
#          'title': 'Terminals',
#          'description': 'The IDs of spaces which must match the codomain of the parent block.',
#          'items': {'type': 'string'}}},
#        'required': ['ID', 'Name', 'Parent', 'Port', 'Terminals']}},
#      'Wires': {'type': 'array',
#       'description': 'A list of wires in the block diagram protocol that follow the wire schema.',
#       'title': 'Wires',
#       'items': {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/wire.schema.json',
#        '$schema': 'http://json-schema.org/draft-07/schema#',
#        'title': 'Wire Schema',
#        'type': 'object',
#        'additionalProperties': False,
#        'properties': {'ID': {'type': 'string',
#          'title': 'ID',
#          'description': 'A unique identifier for the wire.'},
#         'Parent': {'type': 'string',
#          'title': 'Parent',
#          'description': 'The ID of the space that the wire is passing.'},
#         'Source': {'type': 'object',
#          'title': 'Source',
#          'description': 'The source of the wire/space.',
#          'properties': {'Processor': {'type': 'string',
#            'title': 'Processor',
#            'description': 'The ID of the processor that the wire is coming from.'},
#           'Index': {'type': 'integer',
#            'title': 'Index',
#            'description': 'The index of the terminal that the wire is coming from.'}}},
#         'Target': {'type': 'object',
#          'title': 'Target',
#          'description': 'The target of the wire/space.',
#          'properties': {'Processor': {'type': 'string',
#            'title': 'Processor',
#            'description': 'The ID of the processor that the wire is going to.'},
#           'Index': {'type': 'integer',
#            'title': 'Index',
#            'description': 'The index of the port that the wire is going to.'}}}},
#        'required': ['ID',
#         'Parent',
#         'SourceBlock',
#         'TargetBlock',
#         'SourceIndex',
#         'TargetIndex']}},
#      'Systems': {'type': 'array',
#       'description': 'A list of systems in the block diagram protocol that follow the system schema.',
#       'title': 'Systems',
#       'items': {'$id': 'https://github.com/BlockScience/bdp-lib/tree/main/src/bdp_lib/schemas/system.schema.json',
#        '$schema': 'http://json-schema.org/draft-07/schema#',
#        'title': 'System Schema',
#        'type': 'object',
#        'additionalProperties': False,
#        'properties': {'ID': {'type': 'string',
#          'title': 'ID',
#          'description': 'A unique identifier for the system.'},
#         'Name': {'type': 'string',
#          'title': 'Name',
#          'description': 'The name of the system.'},
#         'Description': {'type': 'string',
#          'title': 'Description',
#          'description': 'A description of the system.'},
#         'ConcreteBlocks': {'type': 'array',
#          'title': 'ConcreteBlocks',
#          'description': 'A list of concrete block IDs that are part of the system.',
#          'items': {'type': 'string'}},
#         'Wires': {'type': 'array',
#          'title': 'Wires',
#          'description': 'A list of wire IDs that are part of the system.',
#          'items': {'type': 'string'}}},
#        'required': ['ID', 'Name', 'ConcreteBlocks', 'Wires']}}},
#     'required': ['Processors', 'Wires', 'Systems']}}},
#  'required': ['Toolbox', 'Model']}

# %%
with open("toolbox.schema.json", "r") as file:
    data = jsonref.load(file)  # Parses JSON into a Python dictionary

# %%
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/urllib/request.py:1503, in FileHandler.open_local_file(self, req)
#    1502 try:
# -> 1503     stats = os.stat(localfile)
#    1504     size = stats.st_size
#
# FileNotFoundError: [Errno 2] No such file or directory: ''
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/jsonref.py:130, in JsonRef.callback(self)
#     129 try:
# --> 130     base_doc = self.loader(uri)
#     131 except Exception as e:
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/jsonref.py:255, in jsonloader(uri, **kwargs)
#     253 else:
#     254     # Otherwise, pass off to urllib and assume utf-8
# --> 255     with urlopen(uri) as content:
#     256         result = json.loads(content.read().decode("utf-8"), **kwargs)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/urllib/request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/urllib/request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/urllib/request.py:534, in OpenerDirector._open(self, req, data)
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/urllib/request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     493 func = getattr(handler, meth_name)
# --> 494 result = func(*args)
#     495 if result is not None:
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/urllib/request.py:1481, in FileHandler.file_open(self, req)
#    1480 else:
# -> 1481     return self.open_local_file(req)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/urllib/request.py:1520, in FileHandler.open_local_file(self, req)
#    1519 except OSError as exp:
# -> 1520     raise URLError(exp)
#    1521 raise URLError('file not on local host')
#
# URLError: <urlopen error [Errno 2] No such file or directory: ''>
#
# The above exception was the direct cause of the following exception:
#
# JsonRefError                              Traceback (most recent call last)
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/core/formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/lib/pretty.py:692, in _dict_pprinter_factory.<locals>.inner(obj, p, cycle)
#     690     p.pretty(key)
#     691     p.text(': ')
# --> 692     p.pretty(obj[key])
#     693 p.end_group(step, end)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/lib/pretty.py:692, in _dict_pprinter_factory.<locals>.inner(obj, p, cycle)
#     690     p.pretty(key)
#     691     p.text(': ')
# --> 692     p.pretty(obj[key])
#     693 p.end_group(step, end)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/lib/pretty.py:692, in _dict_pprinter_factory.<locals>.inner(obj, p, cycle)
#     690     p.pretty(key)
#     691     p.text(': ')
# --> 692     p.pretty(obj[key])
#     693 p.end_group(step, end)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/IPython/lib/pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/proxytypes.py:121, in ProxyMetaClass._no_proxy.<locals>.wrapper(self, *args, **kwargs)
#     119 _osa(self, "__notproxied__", True)
#     120 try:
# --> 121     return method(self, *args, **kwargs)
#     122 finally:
#     123     _osa(self, "__notproxied__", notproxied)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/jsonref.py:199, in JsonRef.__repr__(self)
#     197 def __repr__(self):
#     198     if hasattr(self, "cache") or self.load_on_repr:
# --> 199         return repr(self.__subject__)
#     200     return "JsonRef(%r)" % self.__reference__
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/proxytypes.py:163, in Proxy.__getattribute__(self, attr)
#     161 if Proxy._should_proxy(self, attr):
#     162     return getattr(self.__subject__, attr)
# --> 163 return _oga(self, attr)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/proxytypes.py:121, in ProxyMetaClass._no_proxy.<locals>.wrapper(self, *args, **kwargs)
#     119 _osa(self, "__notproxied__", True)
#     120 try:
# --> 121     return method(self, *args, **kwargs)
#     122 finally:
#     123     _osa(self, "__notproxied__", notproxied)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/proxytypes.py:243, in LazyProxy.__subject__(self)
#     240 except AttributeError:
#     241     pass
# --> 243 self.cache = super(LazyProxy, self).__subject__
#     244 return self.cache
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/proxytypes.py:121, in ProxyMetaClass._no_proxy.<locals>.wrapper(self, *args, **kwargs)
#     119 _osa(self, "__notproxied__", True)
#     120 try:
# --> 121     return method(self, *args, **kwargs)
#     122 finally:
#     123     _osa(self, "__notproxied__", notproxied)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/proxytypes.py:227, in CallbackProxy.__subject__(self)
#     225 @property
#     226 def __subject__(self):
# --> 227     return self.callback()
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/proxytypes.py:121, in ProxyMetaClass._no_proxy.<locals>.wrapper(self, *args, **kwargs)
#     119 _osa(self, "__notproxied__", True)
#     120 try:
# --> 121     return method(self, *args, **kwargs)
#     122 finally:
#     123     _osa(self, "__notproxied__", notproxied)
#
# File ~/opt/anaconda3/envs/MSML/lib/python3.9/site-packages/jsonref.py:132, in JsonRef.callback(self)
#     130         base_doc = self.loader(uri)
#     131     except Exception as e:
# --> 132         raise self._error(
#     133             "%s: %s" % (e.__class__.__name__, str(e)), cause=e
#     134         ) from e
#     135     base_doc = _replace_refs(
#     136         base_doc, **{**self._ref_kwargs, "base_uri": uri, "recursing": False}
#     137     )
#     138 else:
#
# JsonRefError: Error while resolving `file://space.schema.json`: URLError: <urlopen error [Errno 2] No such file or directory: ''>

# %%
os.listdir(".")
# Out:
# ['block.schema.json',
#  'model.schema.json',
#  'bdp.schema.json',
#  'toolbox.schema.json',
#  'processor.schema.json',
#  'system.schema.json',
#  'wire.schema.json',
#  'space.schema.json']
